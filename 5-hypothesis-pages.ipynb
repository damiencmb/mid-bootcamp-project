# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# # We want to know if a book has a better rating when the number of pages is not high

# %%
df = pd.read_csv('df_for_analysis.csv')

# %% [markdown]
# For a fair comparaison we take only the books rated more than a hundred thousand time.

# %%
df = df[(df['numRatings']> 100000)]

# %%
df.to_csv('number_ratings_filtered.csv', index=False)

# %%
df['pages'].mean()
# Out:
# 379.8978742245287

# %% [markdown]
# We will study a sample of the 25% top rated books.

# %%
top25 = df['rating'].quantile(q=0.75)
top25
# Out:
# 4.21

# %%
top25 = df[(df['rating']> 4.21)]
top25
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 5                             19063.The_Book_Thief
# ...                                            ...
# 21275                     9647295-the-way-of-kings
# 27293                  43925876-the-giver-of-stars
# 32752                     9188338-the-way-of-kings
# 37109               147732.Miss_Nelson_Is_Missing_
# 38842                  51791252-the-vanishing-half
#
#                                            title             author  \
# 0                               The Hunger Games    Suzanne Collins
# 1      Harry Potter and the Order of the Phoenix       J.K. Rowling
# 2                          To Kill a Mockingbird         Harper Lee
# 3                            Pride and Prejudice        Jane Austen
# ...

# %%
from scipy.stats import ttest_1samp

# H0 = pages top rated books <= mean pages
# H1 = pages top rated books > mean pages

stat, pval = ttest_1samp(top25['pages'], 380)

print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval/2)
# Out:
# stat is   4.4442647682936265
# pvalue for the two-tailed test is  5.7976914089176346e-06

# %% [markdown]
# The p value is very low but the stat is positive whereas the null hypothesis was 'less than' so we can reject the null hypothesis.

# %% [markdown]
# # A book is not better rated because it has a low number of pages.
