# %% [markdown]
# # For this project, we're going to look at the parameters that make a book well rated

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('books_1.Best_Books_Ever.csv') 
df
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# ...

# %% [markdown]
# # We first drop all the duplicates rows.

# %%
df.drop_duplicates(keep=False)
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# ...

# %% [markdown]
# # Then we check which columns are relevant and which are not, which we keep as they are and which we can modify

# %%
df.isna().sum()
# Out:
# bookId                  0
# title                   0
# series              29008
# author                  0
# rating                  0
# description          1338
# language             3806
# isbn                    0
# genres                  0
# characters              0
# bookFormat           1473
# edition             47523
# pages                2347
# publisher            3696
# publishDate           880
# firstPublishDate    21326
# awards                  0
# numRatings              0
# ratingsByStars          0
# likedPercent          622
# setting                 0
# coverImg              605
# bbeScore                0
# bbeVotes                0
# price               14365
# dtype: int64

# %%
df.nunique()
# Out:
# bookId              52424
# title               49927
# series              22802
# author              28227
# rating                261
# description         50888
# language               81
# isbn                48072
# genres              44154
# characters          12448
# bookFormat            136
# edition              1788
# pages                1365
# publisher           11110
# publishDate         10635
# firstPublishDate     8024
# awards               9215
# numRatings          19347
# ratingsByStars      49908
# likedPercent           66
# setting              4651
# coverImg            51819
# bbeScore             3541
# bbeVotes              649
# price                3776
# dtype: int64

# %%
df.dtypes
# Out:
# bookId               object
# title                object
# series               object
# author               object
# rating              float64
# description          object
# language             object
# isbn                 object
# genres               object
# characters           object
# bookFormat           object
# edition              object
# pages                object
# publisher            object
# publishDate          object
# firstPublishDate     object
# awards               object
# numRatings            int64
# ratingsByStars       object
# likedPercent        float64
# setting              object
# coverImg             object
# bbeScore              int64
# bbeVotes              int64
# price                object
# dtype: object

# %% [markdown]
# #### Not relevant :
# - 'description' column since it's quite only unique string values
# - 'isbn' is a unique value for each book, it's not relevant
# - 'characters' are different for each book, we drop it
# - 'edition' to many unique values
# - 'setting' to many unique values and NaN
# - 'coverImg', just the url of book cover
#
# #### Keep as it is :
# - 'bookID'
# - 'title'
# - 'author'
# - 'rating' is our target
# - 'language'
# - 'genre'
# - 'bookFormat'
# - 'pages'
# - 'publisher'
# - 'numRatings'
# - 'likedPercent'
# - 'bbeScore'
# - 'bbeVotes'
#
# #### Rearange :
# - 'series' yes if something oherwise no
# - 'pages' into int
# - 'publishDate' into datetime format and bins
# - 'firstPublishDate' into datetime format and bins
# - 'awards' yes/no (1/0)
# - 'ratingsByStars' 5 column into int
# - 'price' into float

# %%
df = df.drop(['description','isbn','characters','edition','setting','coverImg'], axis=1)
df
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# ...

# %% [markdown]
# # We now replace the NaN values for the relevant columns and do the other necessary changes

# %% [markdown]
# ### 1. Series

# %%
df['series'].value_counts()
# Out:
# Star Wars Legends                 15
# Sherlock Holmes                   13
# Dear America                      12
# The Society On Da Run             11
# Duluoz Legend                     10
#                                   ..
# Cotton Malone #1                   1
# Dirk Pitt #19                      1
# Incarnations of Immortality #3     1
# Bad Kitty #1                       1
# Stripling Warrior #1               1
# Name: series, Length: 22802, dtype: int64

# %% [markdown]
# Some values have the number of appearance in the serie but others do not. If they had all had the number, we could have kept only the number, but as this is not the case, we'll replace with 'yes' for books belonging to a series and 'no' for NaN values.

# %%
df['series']= df['series'].fillna('No')

df['series'] = np.where(df['series'] == 'No', 'No', 'Yes')

df['series'].value_counts(dropna=False)
# Out:
# No     29008
# Yes    23470
# Name: series, dtype: int64

# %% [markdown]
# ### 2. Language

# %%
df['language'].value_counts(dropna=False)
# Out:
# English                                  42661
# NaN                                       3806
# Arabic                                    1038
# Spanish                                    687
# French                                     579
#                                          ...
# Aromanian; Arumanian; Macedo-Romanian        1
# Basque                                       1
# Faroese                                      1
# Iranian (Other)                              1
# Norwegian Nynorsk; Nynorsk, Norwegian        1
# Name: language, Length: 82, dtype: int64

# %%
df[df['language'].isna()]
# Out:
#                                           bookId  \
# 503                34521870-mistress-suffragette
# 570                  36236125-invisible-monsters
# 645               38311414-house-of-sand-and-fog
# 703                       41423092-the-awakening
# 751    7770.One_Fish_Two_Fish_Red_Fish_Blue_Fish
# ...                                          ...
# 52411                        21691391-pixie-dust
# 52416                       23014216-when-i-fall
# 52429   20665259-did-god-really-command-genocide
# 52454                     13254398-au-petit-poil
# 52464                         36374396-algedonic
#
#                                                    title series  \
# 503                                 Mistress Suffragette     No
# 570                                   Invisible Monsters     No
# 645                                House of Sand and Fog     No
# 703                        The Awakening: Fate in Motion     No
# ...

# %% [markdown]
# Since most of the books of the dataset are in English and most of the books in the world are translated in English, we replace the NaN values by the mode.

# %%
df['language'].fillna(df['language'].mode()[0], inplace=True)

df['language'].value_counts(dropna=False)
# Out:
# English                                  46467
# Arabic                                    1038
# Spanish                                    687
# French                                     579
# German                                     528
#                                          ...
# Aromanian; Arumanian; Macedo-Romanian        1
# Basque                                       1
# Faroese                                      1
# Iranian (Other)                              1
# Norwegian Nynorsk; Nynorsk, Norwegian        1
# Name: language, Length: 81, dtype: int64

# %% [markdown]
# ### 3. Book Format

# %%
df['bookFormat'].value_counts(dropna=False)
# Out:
# Paperback                26773
# Hardcover                12268
# Kindle Edition            5834
# Mass Market Paperback     2567
# ebook                     2547
#                          ...
# capa mole                    1
# Box-Set                      1
# Paperback, eBook             1
# paper book                   1
# pamphlet                     1
# Name: bookFormat, Length: 137, dtype: int64

# %% [markdown]
# It seems that most of the books are paperback format but it's less than 50% of the dataset so we don't use the mode but replace the NaN values by 'other'.

# %%
df['bookFormat']= df['bookFormat'].fillna('Other')

df['bookFormat'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 4. Pages

# %% [markdown]
# The type of 'pages' column is 'object' because some rows contain values like '1page' so we first need to change it as interger and then we replace the NaN values by the mean.

# %%
df['pages'].isna().sum()
# Out:
# 2347

# %%
# we first need to keep only the numeric part 
df['pages'] = df['pages'].str.extract('(\d+)')

# then we drop de NaN
pages_drop = df['pages'].dropna()

# we convert to interger
pages_int = pages_drop.astype(int)

# we check the mean
pages_int.mean()
# Out:
# 328.51453192635296

# %%
# we replace de NaN with the mean
df['pages'] = df['pages'].fillna(328)

# we check the NaN values
df['pages'].isna().sum()
# Out:
# 0

# %%
# we convert the whole column into integer
df['pages'] = df['pages'].astype(int)
# we check if page is interger
df.dtypes
# Out:
# bookId               object
# title                object
# series               object
# author               object
# rating              float64
# language             object
# genres               object
# bookFormat           object
# pages                 int64
# publisher            object
# publishDate          object
# firstPublishDate     object
# awards               object
# numRatings            int64
# ratingsByStars       object
# likedPercent        float64
# bbeScore              int64
# bbeVotes              int64
# price                object
# dtype: object

# %% [markdown]
# ### 5. Publisher

# %% [markdown]
# We replace the NaN value by 'Other'

# %%
df['publisher'].value_counts(dropna=False)
# Out:
# NaN                   3696
# Vintage                572
# HarperCollins          563
# Penguin Books          430
# Ballantine Books       399
#                       ...
# Bang Ediciones           1
# Book Sales               1
# Dakota Press             1
# Tannbourne Limited       1
# Bonneville               1
# Name: publisher, Length: 11111, dtype: int64

# %%
df['publisher'] = df['publisher'].fillna('Other')
df['publisher'].value_counts(dropna=False)
# Out:
# Other                 3696
# Vintage                572
# HarperCollins          563
# Penguin Books          430
# Ballantine Books       399
#                       ...
# Bang Ediciones           1
# Book Sales               1
# Dakota Press             1
# Tannbourne Limited       1
# Bonneville               1
# Name: publisher, Length: 11111, dtype: int64

# %% [markdown]
# ### 6. Publish date

# %% [markdown]
# For this date column we first need to convert it into datetime format, then we replace the NaN values with the mean.

# %%
df['publishDate'] = pd.to_datetime(df['publishDate'], errors='coerce')
df['publishDate']
# Out:
# 0       2008-09-14
# 1       2004-09-28
# 2       2006-05-23
# 3       2000-10-10
# 4       2006-09-06
#            ...
# 52473   2011-05-28
# 52474   2011-08-05
# 52475   2011-03-18
# 52476   2011-09-01
# 52477   2011-05-08
# Name: publishDate, Length: 52478, dtype: datetime64[ns]

# %%
df['publishDate'].mean()
# Out:
# Timestamp('2006-08-20 10:18:46.451383808')

# %%
df['publishDate'] = df['publishDate'].fillna(df['publishDate'].mean())

# %%
df['publishDate'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 7. First Publish Date

# %% [markdown]
# Since less than the half of the dataset has a first publish date, we will replace the column name by 'severalPublications' and the NaN values by 'No' and the other values by 'Yes'

# %%
df['severalPublications'] = df['firstPublishDate']

df['severalPublications'] = df['severalPublications'].fillna('No')

df['severalPublications'] = np.where(df['severalPublications'] == 'No', 'No', 'Yes')

df['severalPublications'].value_counts(dropna=False)
# Out:
# Yes    31152
# No     21326
# Name: severalPublications, dtype: int64

# %%
df = df.drop(columns=['firstPublishDate'])
df
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title series  \
# 0                               The Hunger Games    Yes
# 1      Harry Potter and the Order of the Phoenix    Yes
# 2                          To Kill a Mockingbird    Yes
# 3                            Pride and Prejudice     No
# 4                                       Twilight    Yes
# ...

# %% [markdown]
# ### 8. Awards

# %% [markdown]
# The 'awards' columon does not have any NaN values but instead '[]' is written. We replace these values by 0 (=No) and the other by 1 (=Yes).

# %%
df['awards'] = np.where(df['awards'] == '[]', 0, 1)

df['awards'].value_counts(dropna=False)
# Out:
# 0    41864
# 1    10614
# Name: awards, dtype: int64

# %% [markdown]
# ### 9. LikedPercent

# %% [markdown]
# We keep this column for later as we may probably fill the NaN values with a computation based on other columns including ratings by stars which we haven't cleaned yet.

# %% [markdown]
# ### 10. Price

# %% [markdown]
# We first need the convert the price into float and then replace the NaN values by the mean.

# %%
# df['price'] = df['price'].astype(float)

# %% [markdown]
# I got this message error : ValueError: could not convert string to float: '1.189.88'

# %% [markdown]
# It seems that that this price book is not in dollar but we can not guess which currency it is so we check how many row have this unusal price format and drop it if there are not too many.

# %%
# we frist drop the NaN 
rows = df['price'].dropna()

# then we look for the unsual price pattern
pattern = '^\d+\.\d+\.\d+$'

# we check the number of rows with this price pattern
rowspattern = rows.str.match(pattern)
rowspattern.value_counts()
# Out:
# False    38101
# True        12
# Name: price, dtype: int64

# %%
# We create a new boolean column 
df['boolprice'] = rowspattern

# We check of the unsual prices fomart are there
rowstrue = df[(df['boolprice']==True)]
rowstrue
# Out:
#                                                   bookId  \
# 5067                                             3018318
# 14042  1523598.The_Cloister_and_the_Hearth_Volume_Thr...
# 18388                          6895403-ferrari-in-camera
# 20913                                        815760.Cows
# 23764                                       2670656-eros
# 28279                          162374.Way_Of_The_Samurai
# 28671                     388304.The_Oxford_India_Ghalib
# 29421     10118917-the-commander-and-the-den-asaan-rautu
# 29684  117486.Capitale_de_la_douleur_suivi_de_L_amour...
# 34805                        194649.The_Law_and_the_Lady
# 48594                            106212.National_Lampoon
# 52240  3032006-la-est-tica-musical-desde-la-antig-eda...
#
#                                                    title series  \
# 5067                                              جدارية     No
# 14042  The Cloister and the Hearth, Volume Three of F...     No
# ...

# %%
# we drop the unsual pattern rows
df = df[df['boolprice'] != True]

# %%
# we drop the column 'boolprice'
df = df.drop(columns=['boolprice'])

# we convert the 'price' column into float
df['price'] = df['price'].astype(float)

# %% [markdown]
# We now replace the NaN values by the mean.

# %%
df['price'] = df['price'].fillna(df['price'].mean())

# %%
df.isna().sum()
# Out:
# bookId                   0
# title                    0
# series                   0
# author                   0
# rating                   0
# language                 0
# genres                   0
# bookFormat               0
# pages                    0
# publisher                0
# publishDate              0
# awards                   0
# numRatings               0
# ratingsByStars           0
# likedPercent           622
# bbeScore                 0
# bbeVotes                 0
# price                    0
# severalPublications      0
# dtype: int64

# %%
# Now that we have cleaned all the NaN values, we save the new dataframe in a csv file to reuse it for further analysis

# %%
# df.to_csv('df_cleaned_NaN.csv', index=False)

# %%
# df.dtypes
# Out:
# bookId                         object
# title                          object
# series                         object
# author                         object
# rating                        float64
# language                       object
# genres                         object
# bookFormat                     object
# pages                           int64
# publisher                      object
# publishDate            datetime64[ns]
# awards                          int64
# numRatings                      int64
# ratingsByStars                 object
# likedPercent                  float64
# bbeScore                        int64
# bbeVotes                        int64
# price                         float64
# severalPublications            object
# dtype: object

# %% [markdown]
# # Now let's take a closer look at the column 'likedPercent'

# %% [markdown]
# This column correspond to the the sum of 3 stars or more divided by the sum of the total total stars time 100. We are gonna fill the NaN values with this number, but first we need to seperate the column ratingsByStars in 5, one for each number of stars ratings.

# %% [markdown]
# ## 1. Ratings by stars

# %%
# we first remove the apostrophes and square brackets
df['ratingsByStars'] = [e.replace("'", "") for e in df['ratingsByStars']]
df['ratingsByStars'] = [e.replace("[", "") for e in df['ratingsByStars']]
df['ratingsByStars'] = [e.replace("]", "") for e in df['ratingsByStars']]
df.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title series  \
# 0                           The Hunger Games    Yes
# 1  Harry Potter and the Order of the Phoenix    Yes
# 2                      To Kill a Mockingbird    Yes
# 3                        Pride and Prejudice     No
# 4                                   Twilight    Yes
#
#                                       author  rating language  \
# 0                            Suzanne Collins    4.33  English
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50  English
# 2                                 Harper Lee    4.28  English
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26  English
# ...

# %%
# then we split the values on the coma
df[['5*', '4*', '3*', '2*', '1*']] = df['ratingsByStars'].str.split(',', expand=True)
df = df.drop(columns=['ratingsByStars'])
df
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title series  \
# 0                               The Hunger Games    Yes
# 1      Harry Potter and the Order of the Phoenix    Yes
# 2                          To Kill a Mockingbird    Yes
# 3                            Pride and Prejudice     No
# 4                                       Twilight    Yes
# ...

# %%
df.isna().sum()
# Out:
# bookId                    0
# title                     0
# series                    0
# author                    0
# rating                    0
# language                  0
# genres                    0
# bookFormat                0
# pages                     0
# publisher                 0
# publishDate               0
# awards                    0
# numRatings                0
# likedPercent            622
# bbeScore                  0
# bbeVotes                  0
# price                     0
# severalPublications       0
# 5*                        0
# 4*                     1421
# 3*                     1421
# 2*                     1421
# 1*                     1421
# dtype: int64

# %% [markdown]
# We suppose that NaN values for star ratings are because people only gave a 5 stars rating so we replace them by 0.

# %%
df[['5*', '4*', '3*', '2*', '1*']] = df[['5*', '4*', '3*', '2*', '1*']].fillna(0)
df.isna().sum()
# Out:
# bookId                   0
# title                    0
# series                   0
# author                   0
# rating                   0
# language                 0
# genres                   0
# bookFormat               0
# pages                    0
# publisher                0
# publishDate              0
# awards                   0
# numRatings               0
# likedPercent           622
# bbeScore                 0
# bbeVotes                 0
# price                    0
# severalPublications      0
# 5*                       0
# 4*                       0
# 3*                       0
# 2*                       0
# 1*                       0
# dtype: int64

# %% [markdown]
# ## 2. Liked Percent

# %%
# df['likedPercent'] = (df['5*']+df['4*']+df['3*'])/(df['5*']+df['4*']+df['3*']+df['2*']+df['1*'])*100

# %% [markdown]
# We are gonna fill the NaN values with this computation.

# %%
# df['likedPercent'] = df['likedPercent'].fillna((df['5*']+df['4*']+df['3*'])/(df['5*']+df['4*']+df['3*']+df['2*']+df['1*'])*100)

# %% [markdown]
# We got this error message : TypeError: can only concatenate str (not "int") to str

# %%
df.dtypes
# Out:
# bookId                         object
# title                          object
# series                         object
# author                         object
# rating                        float64
# language                       object
# genres                         object
# bookFormat                     object
# pages                           int64
# publisher                      object
# publishDate            datetime64[ns]
# awards                          int64
# numRatings                      int64
# likedPercent                  float64
# bbeScore                        int64
# bbeVotes                        int64
# price                         float64
# severalPublications            object
# 5*                             object
# 4*                             object
# 3*                             object
# 2*                             object
# 1*                             object
# dtype: object

# %% [markdown]
# We need to convert the stars columns which are object type into numeric type.

# %%
# df[['5*','4*','3*','2*','1*']] = df[['5*','4*','3*','2*','1*']].astype(float)

# %% [markdown]
# Error message : 'ValueError: could not convert string to float'.\
# We suppose that an empty value is where there's no rating, so equal we replace it by zero.

# %%
df['5*'] = df['5*'].replace('', 0)

# %%
df[['5*','4*','3*','2*','1*']] = df[['5*','4*','3*','2*','1*']].astype(float)

# %%
df.dtypes
# Out:
# bookId                         object
# title                          object
# series                         object
# author                         object
# rating                        float64
# language                       object
# genres                         object
# bookFormat                     object
# pages                           int64
# publisher                      object
# publishDate            datetime64[ns]
# awards                          int64
# numRatings                      int64
# likedPercent                  float64
# bbeScore                        int64
# bbeVotes                        int64
# price                         float64
# severalPublications            object
# 5*                            float64
# 4*                            float64
# 3*                            float64
# 2*                            float64
# 1*                            float64
# dtype: object

# %%
df.isna().sum()
# Out:
# bookId                   0
# title                    0
# series                   0
# author                   0
# rating                   0
# language                 0
# genres                   0
# bookFormat               0
# pages                    0
# publisher                0
# publishDate              0
# awards                   0
# numRatings               0
# likedPercent           622
# bbeScore                 0
# bbeVotes                 0
# price                    0
# severalPublications      0
# 5*                       0
# 4*                       0
# 3*                       0
# 2*                       0
# 1*                       0
# dtype: int64

# %% [markdown]
# Now that all the stars columns are cleaned, we fill the column 'likedPercent' with the appropriate computation.

# %%
likedPercent = (df['5*']+df['4*']+df['3*'])/(df['5*']+df['4*']+df['3*']+df['2*']+df['1*'])*100

# %%
df['likedPercent'] = df['likedPercent'].fillna(likedPercent)

# %%
df.isna().sum()
# Out:
# bookId                   0
# title                    0
# series                   0
# author                   0
# rating                   0
# language                 0
# genres                   0
# bookFormat               0
# pages                    0
# publisher                0
# publishDate              0
# awards                   0
# numRatings               0
# likedPercent           622
# bbeScore                 0
# bbeVotes                 0
# price                    0
# severalPublications      0
# 5*                       0
# 4*                       0
# 3*                       0
# 2*                       0
# 1*                       0
# dtype: int64

# %% [markdown]
# We still have NaN values, probably because the in some columns, the number we try to devided is equal to zero.

# %%
(df['5*']+df['4*']+df['3*']+df['2*']+df['1*']).value_counts()
# Out:
# 0.0        1421
# 5.0         243
# 6.0         228
# 7.0         188
# 12.0        187
#            ...
# 86810.0       1
# 35514.0       1
# 73776.0       1
# 8067.0        1
# 14868.0       1
# Length: 19342, dtype: int64

# %% [markdown]
# We now replace the NaN values left by zero.

# %%
df['likedPercent'] = df['likedPercent'].fillna(0)
df.isna().sum()
# Out:
# bookId                 0
# title                  0
# series                 0
# author                 0
# rating                 0
# language               0
# genres                 0
# bookFormat             0
# pages                  0
# publisher              0
# publishDate            0
# awards                 0
# numRatings             0
# likedPercent           0
# bbeScore               0
# bbeVotes               0
# price                  0
# severalPublications    0
# 5*                     0
# 4*                     0
# 3*                     0
# 2*                     0
# 1*                     0
# dtype: int64

# %%
df.dtypes
# Out:
# bookId                         object
# title                          object
# series                         object
# author                         object
# rating                        float64
# language                       object
# genres                         object
# bookFormat                     object
# pages                           int64
# publisher                      object
# publishDate            datetime64[ns]
# awards                          int64
# numRatings                      int64
# likedPercent                  float64
# bbeScore                        int64
# bbeVotes                        int64
# price                         float64
# severalPublications            object
# 5*                            float64
# 4*                            float64
# 3*                            float64
# 2*                            float64
# 1*                            float64
# dtype: object

# %% [markdown]
# Now the dataset is totaly cleaned with 0 NaN value and appropriate type, we can save it in a new csv file.

# %%
df.to_csv('df_cleaned.csv', index=False)
